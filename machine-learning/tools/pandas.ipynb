# %% [markdown]
# ## Defining a Panda series

# %%
import pandas as pd
import numpy as np

# %%
s1 = pd.Series([10, 20, 30, 40, 50])

# %%
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s2 = pd.Series([1.2, 2.3, 4.5])
# Out:
# 0    1.2
# 1    2.3
# 2    4.5
# dtype: float64

# %%
s3 = pd.Series([1,2,3,4,5], index=['a', 'b', 'c', 'd', 'e'])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s1[2]
# Out:
# np.int64(30)

# %%
s4 = s3 + 5
s4
# Out:
# a     6
# b     7
# c     8
# d     9
# e    10
# dtype: int64

# %% [markdown]
# ## Filtering

# %%
s2 = s1[s1>20]
s2
# Out:
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# ## Numpy and Pandas together

# %%
arr = np.array([10,20,30,40,50])
print(arr)
s = pd.Series(arr)
s
# Out:
# [10 20 30 40 50]
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
t = np.sqrt(s)
print(t)
# Out:
# 0    3.162278
# 1    4.472136
# 2    5.477226
# 3    6.324555
# 4    7.071068
# dtype: float64

# %%
indexes = ['a', 'b', 'c', 'd']
arrs = [1,2,3,4]

s = pd.Series(arrs, indexes)
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
s.size
# Out:
# 4

# %% [markdown]
# ### Average of elements

# %%
s1 = pd.Series([10,20,30,40,50])
s1.mean()
# Out:
# np.float64(30.0)

# %%
s1.max()
# Out:
# 50

# %%
s1.min()
# Out:
# 10

# %%
print(s1.sort_values(ascending=True))
print(s1) # Not changes, use s1 = s1.sort_values() to update
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# ## Removing duplicates

# %%
s1 = pd.Series([1,2,3,4,5,2])
print(s1.unique())
s1 = pd.Series(s1.unique())
print(s1)
print(s1.nunique())
# Out:
# [1 2 3 4 5]
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# 5

# %% [markdown]
# ## Get statistics of a series

# %%
s1.describe()
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %% [markdown]
# ## Creating a dataframe

# %%
df = pd.DataFrame(s1)
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %% [markdown]
# ### Create a dataframe using dictionary

# %%
names = ["Virat", "Rohit"]
teams = ["RCB", "MI"]
_dict = {"Name": names, "Team": teams}

df = pd.DataFrame(_dict)
df
# Out:
#     Name Team
# 0  Virat  RCB
# 1  Rohit   MI

# %% [markdown]
# ### Using list

# %%
l = [{'name': 'Virat', 'team': 'RCB'},
     {'name': "Rohit", 'team': 'MI'}]
df = pd.DataFrame(l)
df
# Out:
#     name team
# 0  Virat  RCB
# 1  Rohit   MI

# %%
for (ind, val) in df.iterrows():
    print(f"Row index: {ind}")
    print(f"Row value: {val}")
    print("\n")
# Out:
# Row index: 0
# Row value: name    Virat
# team      RCB
# Name: 0, dtype: object
#
#
# Row index: 1
# Row value: name    Rohit
# team       MI
# Name: 1, dtype: object

# %%
for (ind, val) in df.items():
    print(f"Row index: {ind}")
    print(f"Row value: {val}")
    print("\n")
# Out:
# Row index: name
# Row value: 0    Virat
# 1    Rohit
# Name: name, dtype: object
#
#
# Row index: team
# Row value: 0    RCB
# 1     MI
# Name: team, dtype: object

# %% [markdown]
# ### Drop column/Row

# %%
s = pd.Series([10,15,18,22])
df = pd.DataFrame(s)
df.columns = ['Col1']
df['Col2'] = 20
df['Col3'] = df['Col2'] + df['Col1']
df
# Out:
#    Col1  Col2  Col3
# 0    10    20    30
# 1    15    20    35
# 2    18    20    38
# 3    22    20    42

# %%
df1 = df.drop(index=[1], axis=0)
df1
# Out:
#    Col1  Col2  Col3
# 0    10    20    30
# 2    18    20    38
# 3    22    20    42

# %% [markdown]
# ### Boolean indexing

# %%
_dict = {'Name': ['Saurabh', 'Akash', 'Vikas'],
         'Age': [50, 34, 29]}

df = pd.DataFrame(_dict, index = [True, True, False])
df
# Out:
#           Name  Age
# True   Saurabh   50
# True     Akash   34
# False    Vikas   29

# %%
print(df.loc[True])
# Out:
#          Name  Age
# True  Saurabh   50
# True    Akash   34

# %% [markdown]
# ### DataFrame.loc

# %%
# importing pandas as pd
import pandas as pd

# Creating the DataFrame
df = pd.DataFrame({"A":[12, 4, 5, None, 1],
                "B":[7, 2, 54, 3, None],
                "C":[20, 16, 11, 3, 8],
                "D":[14, 3, None, 2, 6]})

# Create the index
index_ = ['Row_1', 'Row_2', 'Row_3', 'Row_4', 'Row_5']

# Set the index
df.index = index_

# Print the DataFrame
print("Original DataFrame:")
print(df)

# Corrected column names ('A' and 'D') in the result
result = df.loc[:, ['A', 'D']]

# Print the result
print("\nSelected Columns 'A' and 'D':")
print(result)
# Out:
# Original DataFrame:
#           A     B   C     D
# Row_1  12.0   7.0  20  14.0
# Row_2   4.0   2.0  16   3.0
# Row_3   5.0  54.0  11   NaN
# Row_4   NaN   3.0   3   2.0
# Row_5   1.0   NaN   8   6.0
#
# Selected Columns 'A' and 'D':
#           A     D
# Row_1  12.0  14.0
# Row_2   4.0   3.0
# Row_3   5.0   NaN
# Row_4   NaN   2.0
# Row_5   1.0   6.0

# %%
# importing pandas as pd
import pandas as pd

# Creating the DataFrame
df = pd.DataFrame({"A": [12, 4, 5, None, 1],
                   "B": [7, 2, 54, 3, None],
                   "C": [20, 16, 11, 3, 8],
                   "D": [14, 3, None, 2, 6]})

# Create the index
index_ = ['Row_1', 'Row_2', 'Row_3', 'Row_4', 'Row_5']

# Set the index
df.index = index_

# Print the original DataFrame
print("Original DataFrame:")
print(df)

# Select Rows Between 'Row_2' and 'Row_4'
selected_rows = df.loc['Row_2':'Row_4']
print("\nSelected Rows:")
print(selected_rows)

# Select Columns 'B' through 'D'
selected_columns = df.loc[:, 'B':'D']
print("\nSelected Columns:")
print(selected_columns)
# Out:
# Original DataFrame:
#           A     B   C     D
# Row_1  12.0   7.0  20  14.0
# Row_2   4.0   2.0  16   3.0
# Row_3   5.0  54.0  11   NaN
# Row_4   NaN   3.0   3   2.0
# Row_5   1.0   NaN   8   6.0
#
# Selected Rows:
#          A     B   C    D
# Row_2  4.0   2.0  16  3.0
# Row_3  5.0  54.0  11  NaN
# Row_4  NaN   3.0   3  2.0
#
# Selected Columns:
#           B   C     D
# Row_1   7.0  20  14.0
# Row_2   2.0  16   3.0
# Row_3  54.0  11   NaN
# Row_4   3.0   3   2.0
# Row_5   NaN   8   6.0

# %% [markdown]
# ### DataFrame.concat()

# %%
dict1 = {'id': [1,2,3],
         'Name': ['Saurabh', 'Akash', 'Vikas']}
df1= pd.DataFrame(dict1)

dict2 = {'id': [5],
         'Name': ['Random']}
df2 = pd.DataFrame(dict2)

df3 = pd.concat([df1, df2])
df3
# Out:
#    id     Name
# 0   1  Saurabh
# 1   2    Akash
# 2   3    Vikas
# 0   5   Random

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### # Check the data initial rows

# %%
df.head()

# %% [markdown]
# ### Check the columns

# %%
df.columns

# %% [markdown]
# ### Update the column names

# %% [markdown]
# df.columns = df.columns.str.lower().str.replace(' ', '_')

# %% [markdown]
# ### Check the datatypes

# %%
df.dtypes
# Filter
df.dtypes[df.dtypes == "object"]

# Check the string data columns
str_columns = list(df.dtypes[df.dtypes == "object"].index)

# %% [markdown]
# ### Update the string values

# %%
for col in str_columns:
    df[col] = df[col].str.lower().str.replace(' ', '')

# %% [markdown]
# ### Unique column values

# %%
for col in df.columns:
    print(col)
    print(df[col].unique())

# %% [markdown]
# ### Target distribution

# %%
import seaborn as sns

sns.histplot(df["msrp"][df["msrp"] < 100000], bins=50)

# %% [markdown]
# ### Converting the target to log values

# %% [markdown]
# price_logs = np.log1p(df["msrp"])
# sns.histplot(price_logs, bins=50)

# %% [markdown]
# ### Check for nulls

# %%
df.isnull().sum()
